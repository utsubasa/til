# %% [markdown]
# <a href="https://colab.research.google.com/github/utsubasa/til/blob/master/table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install icrawler

# %%
pip list
# Out:
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.7.1
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   3.2.0
# astor                    0.8.0
# astropy                  3.0.5
# atari-py                 0.1.15
# atomicwrites             1.3.0
# attrs                    19.1.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.7.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# blis                     0.2.4
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.9.216
# botocore                 1.12.216
# Bottleneck               1.2.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.1
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

crawler = GoogleImageCrawler(storage={"root_dir": "images"})
crawler.crawl(keyword="犬", max_num=100)
# Out:
# 2019-09-01 09:26:05,874 - INFO - icrawler.crawler - start crawling...
# 2019-09-01 09:26:05,876 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-09-01 09:26:05,883 - INFO - feeder - thread feeder-001 exit
# 2019-09-01 09:26:05,884 - INFO - icrawler.crawler - starting 1 parser threads...
# 2019-09-01 09:26:05,888 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2019-09-01 09:26:06,479 - INFO - parser - parsing result page https://www.google.com/search?q=%E7%8A%AC&ijn=0&start=0&tbs=&tbm=isch
# 2019-09-01 09:26:07,635 - INFO - downloader - image #1	https://www.asahicom.jp/articles/images/AS20190719000785_commL.jpg
# 2019-09-01 09:26:09,451 - INFO - downloader - image #2	https://www.1242.com/lf/asset/uploads/2018/01/dog-3045116_1280a.jpg
# 2019-09-01 09:26:10,495 - INFO - downloader - image #3	https://www.axa-direct.co.jp/pet/pet-ms/img/media/2018/07/img_akita_kind-dog_kv-710x398.jpg
# ...

# %%
# %ls images/
# Out:
# 000001.jpg  000013.jpg  000025.jpg  000037.jpg  000049.jpg  000061.jpg
# 000002.jpg  000014.jpg  000026.png  000038.jpg  000050.jpg  000062.jpg
# 000003.jpg  000015.jpg  000027.jpg  000039.jpg  000051.png  000063.jpg
# 000004.jpg  000016.jpg  000028.jpg  000040.jpg  000052.jpg  000064.jpg
# 000005.jpg  000017.png  000029.jpg  000041.jpg  000053.jpg  000065.jpg
# 000006.jpg  000018.jpg  000030.jpg  000042.jpg  000054.jpg  000066.jpg
# 000007.jpg  000019.jpg  000031.jpg  000043.jpg  000055.JPG  000067.jpg
# 000008.jpg  000020.jpg  000032.jpg  000044.jpg  000056.jpg
# 000009.jpg  000021.jpg  000033.jpg  000045.jpg  000057.jpg
# 000010.jpg  000022.jpg  000034.png  000046.jpg  000058.jpg
# 000011.jpg  000023.jpg  000035.jpg  000047.JPG  000059.jpg
# 000012.jpg  000024.jpg  000036.jpg  000048.jpg  000060.jpg
